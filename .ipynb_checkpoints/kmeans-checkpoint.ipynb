# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
# df = pd.DataFrame.from_csv('iris.data.csv',names = ['a','b','c','d','e'], index_col = None)
df = pd.read_csv('iris.data.csv',names = ['s_length','s_width','p_length','p_width','i_class'])

# %%
df.head()
# Out:
#    s_length  s_width  p_length  p_width      i_class
# 0       5.1      3.5       1.4      0.2  Iris-setosa
# 1       4.9      3.0       1.4      0.2  Iris-setosa
# 2       4.7      3.2       1.3      0.2  Iris-setosa
# 3       4.6      3.1       1.5      0.2  Iris-setosa
# 4       5.0      3.6       1.4      0.2  Iris-setosa

# %%
y = df['s_width']
x = df['s_length']
plt.scatter(x,y)

# %%
# print(df.i_class.unique())
c_chart = ['red','green','blue']
for idx, val in enumerate(df.i_class.unique()):
    df1 = df[df['i_class'] == val]
    y = df1['s_width']
    x = df1['s_length']
    plt.scatter(x,y, color = c_chart[idx])
plt.title('Iris Graph')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
red_patch = mpatches.Patch(color='red', label='Setosa')
blue_patch = mpatches.Patch(color='blue', label = 'Versicolor')
green_patch = mpatches.Patch(color='green', label = 'Virginica')
plt.legend(handles=[red_patch, blue_patch, green_patch])
plt.show()

# %%
# Determine k.
# Calculate the distance between the new observation and all points in the training set.
# Sort the distances to determine the k nearest neighbors based on the k-th minimum distance.
# Determine the class of those neighbors.
# Determine the majority.

# %%
# set k - pick an odd number
k = 101

# Pick a random row
myrnd = np.random.random_integers(1, len(df), 1)

# make a copy of the randomly selcted row
dfrnd = df.iloc[[myrnd[0]]]

# set the values for length and width from random row for distance calculations

rnd_length = dfrnd['s_length']
rnd_width = dfrnd['s_width']
# print(rnd_length)
# type(rnd_length)

# calculate the distance between the random point and all points in the array based on pythagorean thereom

df['length_dif'] = rnd_length.values.item() - df['s_length']
df['width_dif'] = rnd_width.values.item() - df['s_width']
df['dist'] = np.sqrt(df.length_dif **2 + df.width_dif **2)

# sort the data by distance
dfsort = df.sort(['dist'], ascending = [False])

# create a new df with only k nearest neighbors
dfk = df.head(k)
# dfk['counter'] = 1

# Vote on majority class
setosa_cnt = 0
versicolor_cnt = 0
virginica_cnt = 0

val_list = dfk.i_class.unique().tolist()

# setup variables for counter
# for item in val_list:
#     item + 'counter' = []

for idx, val in enumerate(val_list):
#     'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'
    if val == 'Iris-setosa':
        setosa_cnt = +=1
    elif val == 'Iris-versicolor':
        versicolor_cnt = +=1
    elif val == 'Iris-virginica':
        virginica_cnt +=1
    else print("Unexpected Iris value: stopping")
        break
        
    
    
#     dfk1 = dfk[dfk['i_class'] == val].count()
#     print(dfk1)

#groupby by class
# dfvote = dfk.s_length.groupby(df.i_class).count().max() works
# dfvote2 = pd.DateFrame({'count' : dfk.s_length.groupby(dfk.i_class).count()}).reset_index() doesn't work

# DataFrame({'count' : df1.groupby( [ "Name", "City"] ).size()}).reset_index() example
# print(dfvote,dfvote.idx.value)

# # df[df.a > 1].sum()  
# # idx_val = dfvote.index.tolist()
# # dfvote
# Out:
#   File "<ipython-input-215-2ca28e563764>", line 34
#     item + 'counter' = []
# SyntaxError: can't assign to operator

# %%
idx_val
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
myrnd = np.random.random_integers(1, len(df), 1)
# Out:
# C:\Users\bob071988\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: This function is deprecated. Please call randint(1, 150 + 1) instead
#   if __name__ == '__main__':

# %%
print(myrnd)
print(type(myrnd))
x = myrnd[0]
print(type(x))
# Out:
# [53]
# <type 'numpy.ndarray'>
# <type 'numpy.int32'>

# %%
dfrnd = df.iloc[[myrnd[0]]]
dfrnd.head()
# Out:
#     s_length  s_width  p_length  p_width          i_class
# 53       5.5      2.3         4      1.3  Iris-versicolor

# %%
d1 = np.random.random_integers(1, 6, 1000)
# Out:
# C:\Users\bob071988\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: This function is deprecated. Please call randint(1, 6 + 1) instead
#   if __name__ == '__main__':

# %%
rnd_length = dfrnd['s_length']
rnd_width = dfrnd['s_width']
print(rnd_length)
type(rnd_length)

df['length_dif'] = rnd_length.values.item() - df['s_length']
df['width_dif'] = rnd_width.values.item() - df['s_width']
df['dist'] = np.sqrt(df.length_dif **2 + df.width_dif **2)
# Out:
# 53    5.5
# Name: s_length, dtype: float64

# %%
df.head()
# Out:
#    s_length  s_width  p_length  p_width      i_class  length_dif  width_dif  \
# 0       5.1      3.5       1.4      0.2  Iris-setosa         0.4       -1.2
# 1       4.9      3.0       1.4      0.2  Iris-setosa         0.6       -0.7
# 2       4.7      3.2       1.3      0.2  Iris-setosa         0.8       -0.9
# 3       4.6      3.1       1.5      0.2  Iris-setosa         0.9       -0.8
# 4       5.0      3.6       1.4      0.2  Iris-setosa         0.5       -1.3
#
#        dist
# 0  1.264911
# 1  0.921954
# 2  1.204159
# 3  1.204159
# 4  1.392839

# %%
# test = df.sort(['one'], ascending=[False])
df.sort(['dist'], ascending = [True])
# Out:
# C:\Users\bob071988\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#      s_length  s_width  p_length  p_width          i_class  length_dif  \
# 53        5.5      2.3       4.0      1.3  Iris-versicolor         0.0
# 81        5.5      2.4       3.7      1.0  Iris-versicolor         0.0
# 80        5.5      2.4       3.8      1.1  Iris-versicolor         0.0
# 89        5.5      2.5       4.0      1.3  Iris-versicolor         0.0
# 69        5.6      2.5       3.9      1.1  Iris-versicolor        -0.1
# 113       5.7      2.5       5.0      2.0   Iris-virginica        -0.2
# 90        5.5      2.6       4.4      1.2  Iris-versicolor         0.0
# 79        5.7      2.6       3.5      1.0  Iris-versicolor        -0.2
# 94        5.6      2.7       4.2      1.3  Iris-versicolor        -0.1
# 92        5.8      2.6       4.0      1.2  Iris-versicolor        -0.3
# 98        5.1      2.5       3.0      1.1  Iris-versicolor         0.4
# 93        5.0      2.3       3.3      1.0  Iris-versicolor         0.5
# 101       5.8      2.7       5.1      1.9   Iris-virginica        -0.3
# 142       5.8      2.7       5.1      1.9   Iris-virginica        -0.3
# 67        5.8      2.7       4.1      1.0  Iris-versicolor        -0.3
# 59        5.2      2.7       3.9      1.4  Iris-versicolor         0.3
# 82        5.8      2.7       3.9      1.2  Iris-versicolor        -0.3
# 119       6.0      2.2       5.0      1.5   Iris-virginica        -0.5
# 121       5.6      2.8       4.9      2.0   Iris-virginica        -0.1
# 62        6.0      2.2       4.0      1.0  Iris-versicolor        -0.5
# 55        5.7      2.8       4.5      1.3  Iris-versicolor        -0.2
# 99        5.7      2.8       4.1      1.3  Iris-versicolor        -0.2
# 60        5.0      2.0       3.5      1.0  Iris-versicolor         0.5
# 114       5.8      2.8       5.1      2.4   Iris-virginica        -0.3
# 57        4.9      2.4       3.3      1.0  Iris-versicolor         0.6
# 64        5.6      2.9       3.6      1.3  Iris-versicolor        -0.1
# 106       4.9      2.5       4.5      1.7   Iris-virginica         0.6
# 96        5.7      2.9       4.2      1.3  Iris-versicolor        -0.2
# 83        6.0      2.7       5.1      1.6  Iris-versicolor        -0.5
# 134       6.1      2.6       5.6      1.4   Iris-virginica        -0.6
# ..        ...      ...       ...      ...              ...         ...
# 46        5.1      3.8       1.6      0.2      Iris-setosa         0.4
# 44        5.1      3.8       1.9      0.4      Iris-setosa         0.4
# 19        5.1      3.8       1.5      0.3      Iris-setosa         0.4
# 144       6.7      3.3       5.7      2.5   Iris-virginica        -1.2
# 124       6.7      3.3       5.7      2.1   Iris-virginica        -1.2
# 143       6.8      3.2       5.9      2.3   Iris-virginica        -1.3
# 22        4.6      3.6       1.0      0.2      Iris-setosa         0.9
# 5         5.4      3.9       1.7      0.4      Iris-setosa         0.1
# 16        5.4      3.9       1.3      0.4      Iris-setosa         0.1
# 52        6.9      3.1       4.9      1.5  Iris-versicolor        -1.4
# 141       6.9      3.1       5.1      2.3   Iris-virginica        -1.4
# 139       6.9      3.1       5.4      2.1   Iris-virginica        -1.4
# 120       6.9      3.2       5.7      2.3   Iris-virginica        -1.4
# 14        5.8      4.0       1.2      0.2      Iris-setosa        -0.3
# 102       7.1      3.0       5.9      2.1   Iris-virginica        -1.6
# 50        7.0      3.2       4.7      1.4  Iris-versicolor        -1.5
# 32        5.2      4.1       1.5      0.1      Iris-setosa         0.3
# 129       7.2      3.0       5.8      1.6   Iris-virginica        -1.7
# 107       7.3      2.9       6.3      1.8   Iris-virginica        -1.8
# 33        5.5      4.2       1.4      0.2      Iris-setosa         0.0
# 125       7.2      3.2       6.0      1.8   Iris-virginica        -1.7
# 130       7.4      2.8       6.1      1.9   Iris-virginica        -1.9
# 15        5.7      4.4       1.5      0.4      Iris-setosa        -0.2
# 109       7.2      3.6       6.1      2.5   Iris-virginica        -1.7
# 105       7.6      3.0       6.6      2.1   Iris-virginica        -2.1
# 118       7.7      2.6       6.9      2.3   Iris-virginica        -2.2
# 122       7.7      2.8       6.7      2.0   Iris-virginica        -2.2
# 135       7.7      3.0       6.1      2.3   Iris-virginica        -2.2
# 117       7.7      3.8       6.7      2.2   Iris-virginica        -2.2
# 131       7.9      3.8       6.4      2.0   Iris-virginica        -2.4
#
#      width_dif      dist
# 53         0.0  0.000000
# 81        -0.1  0.100000
# 80        -0.1  0.100000
# 89        -0.2  0.200000
# 69        -0.2  0.223607
# 113       -0.2  0.282843
# 90        -0.3  0.300000
# 79        -0.3  0.360555
# 94        -0.4  0.412311
# 92        -0.3  0.424264
# 98        -0.2  0.447214
# 93         0.0  0.500000
# 101       -0.4  0.500000
# 142       -0.4  0.500000
# 67        -0.4  0.500000
# 59        -0.4  0.500000
# 82        -0.4  0.500000
# 119        0.1  0.509902
# 121       -0.5  0.509902
# 62         0.1  0.509902
# 55        -0.5  0.538516
# 99        -0.5  0.538516
# 60         0.3  0.583095
# 114       -0.5  0.583095
# 57        -0.1  0.608276
# 64        -0.6  0.608276
# 106       -0.2  0.632456
# 96        -0.6  0.632456
# 83        -0.4  0.640312
# 134       -0.3  0.670820
# ..         ...       ...
# 46        -1.5  1.552417
# 44        -1.5  1.552417
# 19        -1.5  1.552417
# 144       -1.0  1.562050
# 124       -1.0  1.562050
# 143       -0.9  1.581139
# 22        -1.3  1.581139
# 5         -1.6  1.603122
# 16        -1.6  1.603122
# 52        -0.8  1.612452
# 141       -0.8  1.612452
# 139       -0.8  1.612452
# 120       -0.9  1.664332
# 14        -1.7  1.726268
# 102       -0.7  1.746425
# 50        -0.9  1.749286
# 32        -1.8  1.824829
# 129       -0.7  1.838478
# 107       -0.6  1.897367
# 33        -1.9  1.900000
# 125       -0.9  1.923538
# 130       -0.5  1.964688
# 15        -2.1  2.109502
# 109       -1.3  2.140093
# 105       -0.7  2.213594
# 118       -0.3  2.220360
# 122       -0.5  2.256103
# 135       -0.7  2.308679
# 117       -1.5  2.662705
# 131       -1.5  2.830194
#
# [150 rows x 8 columns]
